# %%
# !python ..\scripts\fuse_images.py -t /Users/alsah/tmp/gcv_hw1_data/abc_0050_00500166_5894bbd701b2bb0fc88a6978_007.hdf5 -p /Users/alsah/tmp/gcv_hw1_data/abc_0050_00500166_5894bbd701b2bb0fc88a6978_007__predictions.hdf5 -o /Users/alsah/tmp/gcv_hw1_data/ -r 0.05
# Out:
# Loading ground truth data...
# C:\Users\alsah\Documents\Skoltech\GCV\gcv_v2021.1_hw1\gcv_v2021.1_hw1\gcv_v20211_hw1\utils\hdf5\dataset.py:64: UserWarning: File C:\Users\alsah\tmp\gcv_hw1_data\abc_0050_00500166_5894bbd701b2bb0fc88a6978_007__predictions.hdf5 is not compatible with Hdf5File I/O interface <class 'gcv_v20211_hw1.utils.hdf5.io_struct.HDF5IO'>
#   warnings.warn('File {} is not compatible with Hdf5File I/O interface {}'.format(
#
# 0it [00:00, ?it/s]C:\Users\alsah\anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:976: RuntimeWarning: The required storage space exceeds the available storage space.
# Probable causes: nxest or nyest too small or s is too small. (fp>s)
# 	kx,ky=1,1 nx,ny=4,4 m=4 fp=0.000003 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# C:\Users\alsah\anaconda3\lib\site-packages\scipy\interpolate\_fitpack_impl.py:976: RuntimeWarning: The required storage space exceeds the available storage space.
# ...

# %%
# !python ..\scripts\fuse_images.py -t /Users/alsah/tmp/gcv_hw1_data/high_res/abc_0050_00500166_5894bbd701b2bb0fc88a6978_007.hdf5 -p /Users/alsah/tmp/gcv_hw1_data/high_res/abc_0050_00500166_5894bbd701b2bb0fc88a6978_007__predictions.hdf5 -o /Users/alsah/tmp/gcv_hw1_data/high_res/
